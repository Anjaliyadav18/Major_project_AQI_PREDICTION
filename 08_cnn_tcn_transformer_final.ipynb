# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    Conv1D,
    GlobalAveragePooling1D,
    GlobalAveragePooling2D,
    MultiHeadAttention,
    LayerNormalization,
    Concatenate,
    BatchNormalization
)

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# =========================
# LOAD SEQUENCE DATA
# =========================
X_seq = np.load("../data/X_sequences.npy")
y = np.load("../data/y_targets.npy")
dates = pd.read_csv("../data/sequence_dates.csv")

dates['Date'] = pd.to_datetime(dates['Date'])

print("Sequence shape:", X_seq.shape)

# =========================
# LOAD SATELLITE IMAGES
# =========================
base_folder = "../satellite images"

image_paths = []

for root, dirs, files in os.walk(base_folder):
    for file in files:
        if file.lower().endswith((".png", ".jpg", ".jpeg")):
            image_paths.append(os.path.join(root, file))

print("Total images:", len(image_paths))

IMG_SIZE = (224, 224)

processed_images = []
image_dates = []

for path in image_paths:
    img = Image.open(path).convert("RGB")
    img = img.resize(IMG_SIZE)
    img = np.array(img) / 255.0

    processed_images.append(img)

    filename = os.path.basename(path)
    date_part = filename.split(".")[0]
    image_dates.append(pd.to_datetime(date_part))

processed_images = np.array(processed_images)

print("Image shape:", processed_images.shape)

# =========================
# MATCH DATES
# =========================
image_df = pd.DataFrame({
    'Date': image_dates
})

matched_dates = pd.merge(dates, image_df, on='Date', how='inner')

date_to_seq = {d: i for i, d in enumerate(dates['Date'])}
date_to_img = {d: i for i, d in enumerate(image_dates)}

matched_seq = []
matched_img = []
matched_targets = []

for d in matched_dates['Date']:
    matched_seq.append(X_seq[date_to_seq[d]])
    matched_img.append(processed_images[date_to_img[d]])
    matched_targets.append(y[date_to_seq[d]])

X_img = np.array(matched_img)
X_seq_final = np.array(matched_seq)
y_final = np.array(matched_targets)

print("Matched samples:", X_img.shape[0])

# =========================
# SCALE TARGET
# =========================
scaler = MinMaxScaler()
y_scaled = scaler.fit_transform(y_final.reshape(-1, 1))

# =========================
# TRAIN TEST SPLIT
# =========================
X_img_train, X_img_test, X_seq_train, X_seq_test, y_train, y_test = train_test_split(
    X_img,
    X_seq_final,
    y_scaled,
    test_size=0.2,
    random_state=42
)

# =========================
# IMAGE BRANCH (CNN)
# =========================
base = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

base.trainable = False

img_input = Input(shape=(224, 224, 3))

img = base(img_input)
img = GlobalAveragePooling2D()(img)
img = Dense(64, activation='relu')(img)
img = Dropout(0.4)(img)

# =========================
# TCN + TRANSFORMER BRANCH
# =========================
seq_input = Input(shape=(X_seq_final.shape[1], X_seq_final.shape[2]))

# TCN style causal convolutions
x = Conv1D(
    64,
    kernel_size=3,
    padding='causal',
    dilation_rate=1,
    activation='relu'
)(seq_input)

x = BatchNormalization()(x)

x = Conv1D(
    64,
    kernel_size=3,
    padding='causal',
    dilation_rate=2,
    activation='relu'
)(x)

x = BatchNormalization()(x)

x = Conv1D(
    64,
    kernel_size=3,
    padding='causal',
    dilation_rate=4,
    activation='relu'
)(x)

# Transformer attention
attn = MultiHeadAttention(
    num_heads=4,
    key_dim=16
)(x, x)

x = x + attn
x = LayerNormalization()(x)

x = GlobalAveragePooling1D()(x)

x = Dense(64, activation='relu')(x)
x = Dropout(0.4)(x)

# =========================
# HYBRID FUSION
# =========================
combined = Concatenate()([img, x])

combined = Dense(64, activation='relu')(combined)
combined = Dropout(0.4)(combined)

combined = Dense(32, activation='relu')(combined)

output = Dense(1)(combined)

model = Model(
    inputs=[img_input, seq_input],
    outputs=output
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002),
    loss='mse',
    metrics=['mae']
)

model.summary()

# =========================
# CALLBACKS
# =========================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3
)

# =========================
# TRAIN
# =========================
history = model.fit(
    [X_img_train, X_seq_train],
    y_train,
    validation_split=0.2,
    epochs=30,
    batch_size=16,
    callbacks=[early_stop, reduce_lr]
)

# =========================
# PREDICT
# =========================
pred = model.predict([X_img_test, X_seq_test])

pred_actual = scaler.inverse_transform(pred)
y_actual = scaler.inverse_transform(y_test)

# =========================
# METRICS
# =========================
mae = mean_absolute_error(y_actual, pred_actual)
rmse = np.sqrt(mean_squared_error(y_actual, pred_actual))
r2 = r2_score(y_actual, pred_actual)

print("MAE:", mae)
print("RMSE:", rmse)
print("R2:", r2)

# =========================
# TOLERANCE ACCURACY
# =========================
error = np.abs(y_actual - pred_actual)

correct = np.sum(error <= 50)

accuracy = (correct / len(error)) * 100

print("Model Accuracy:", accuracy, "%")

# =========================
# CATEGORY ACCURACY
# =========================
def get_category(aqi):
    if aqi <= 50:
        return 0
    elif aqi <= 100:
        return 1
    elif aqi <= 200:
        return 2
    elif aqi <= 300:
        return 3
    elif aqi <= 400:
        return 4
    else:
        return 5

actual_cat = np.array([get_category(x[0]) for x in y_actual])
pred_cat = np.array([get_category(x[0]) for x in pred_actual])

category_accuracy = np.mean(actual_cat == pred_cat) * 100

print("AQI Category Accuracy:", category_accuracy, "%")

# =========================
# PLOT
# =========================
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()
# Out:
# Sequence shape: (1083, 14, 13)
# Total images: 544
# Image shape: (544, 224, 224, 3)
# Matched samples: 537
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 14, 13)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 14, 64)    │      2,560 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 14, 64)    │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 14, 64)    │     12,352 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 64)    │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 14, 64)    │     12,352 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 14, 64)    │     16,640 │ conv1d_2[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 14, 64)    │          0 │ conv1d_2[0][0],   │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mobilenetv2_1.00_2… │ (None, 7, 7,      │  2,257,984 │ input_layer_1[0]… │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 14, 64)    │        128 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ mobilenetv2_1.00… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     81,984 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ dropout[0][0],    │
# │ (Concatenate)       │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      8,256 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 32)        │      2,080 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1)         │         33 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,399,041 (9.15 MB)
#  Trainable params: 140,801 (550.00 KB)
#  Non-trainable params: 2,258,240 (8.61 MB)
# Epoch 1/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 27s 642ms/step - loss: 0.7246 - mae: 0.7195 - val_loss: 0.2460 - val_mae: 0.4059 - learning_rate: 2.0000e-04
# Epoch 2/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 368ms/step - loss: 0.2662 - mae: 0.4241 - val_loss: 0.1065 - val_mae: 0.2725 - learning_rate: 2.0000e-04
# Epoch 3/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 365ms/step - loss: 0.1950 - mae: 0.3426 - val_loss: 0.1166 - val_mae: 0.2833 - learning_rate: 2.0000e-04
# Epoch 4/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - loss: 0.1523 - mae: 0.3095 - val_loss: 0.1039 - val_mae: 0.2723 - learning_rate: 2.0000e-04
# Epoch 5/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 356ms/step - loss: 0.1512 - mae: 0.3149 - val_loss: 0.1023 - val_mae: 0.2734 - learning_rate: 2.0000e-04
# Epoch 6/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 359ms/step - loss: 0.1251 - mae: 0.2905 - val_loss: 0.1016 - val_mae: 0.2738 - learning_rate: 2.0000e-04
# Epoch 7/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - loss: 0.1271 - mae: 0.2950 - val_loss: 0.0963 - val_mae: 0.2692 - learning_rate: 2.0000e-04
# Epoch 8/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 370ms/step - loss: 0.1299 - mae: 0.2891 - val_loss: 0.0984 - val_mae: 0.2711 - learning_rate: 2.0000e-04
# Epoch 9/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 368ms/step - loss: 0.1256 - mae: 0.2863 - val_loss: 0.1000 - val_mae: 0.2709 - learning_rate: 2.0000e-04
# Epoch 10/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 355ms/step - loss: 0.1296 - mae: 0.2938 - val_loss: 0.0973 - val_mae: 0.2672 - learning_rate: 2.0000e-04
# Epoch 11/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - loss: 0.1127 - mae: 0.2729 - val_loss: 0.0993 - val_mae: 0.2700 - learning_rate: 1.0000e-04
# Epoch 12/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 10s 355ms/step - loss: 0.1079 - mae: 0.2674 - val_loss: 0.1015 - val_mae: 0.2719 - learning_rate: 1.0000e-04
# Epoch 13/30
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 363ms/step - loss: 0.1069 - mae: 0.2596 - val_loss: 0.0983 - val_mae: 0.2674 - learning_rate: 1.0000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 939ms/step
# MAE: 139.17289185700594
# RMSE: 161.26229265736964
# R2: -0.2029550541023586
# Model Accuracy: 15.74074074074074 %
# AQI Category Accuracy: 12.962962962962962 %
