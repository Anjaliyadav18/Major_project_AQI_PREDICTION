# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("../data/Delhi_AQI_2020_2024_clean.csv")

# Basic checks
print("Dataset Shape:", df.shape)
print("\nDataset Info:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:", df.duplicated().sum())

# Convert date
df['Date'] = pd.to_datetime(df['Date'])

# Sort by date
df = df.sort_values('Date')

# Drop duplicates
df = df.drop_duplicates()

# Fill missing numeric values
df = df.fillna(df.median(numeric_only=True))

# Final check
print("\nAfter Cleaning Missing Values:")
print(df.isnull().sum())

# Save cleaned file
df.to_csv("../data/cleaned_aqi_final.csv", index=False)

# Show first rows
df.head()
# Out:
# Dataset Shape: (1827, 15)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1827 non-null   object
#  1   PM2.5       1827 non-null   float64
#  2   PM10        1827 non-null   float64
#  3   NO          1827 non-null   float64
#  4   NO2         1827 non-null   float64
#  5   NOx         1827 non-null   float64
#  6   NH3         1827 non-null   float64
#  7   CO          1827 non-null   float64
#  8   SO2         1827 non-null   float64
#  9   O3          1827 non-null   float64
#  10  Benzene     1827 non-null   float64
#  11  Toluene     1827 non-null   float64
#  12  Xylene      1827 non-null   float64
#  13  AQI         1827 non-null   float64
#  14  AQI_Bucket  1827 non-null   object
# dtypes: float64(13), object(2)
# memory usage: 214.2+ KB
# None
#
# Missing Values:
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64
#
# Duplicate Rows: 0
#
# After Cleaning Missing Values:
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64
#         Date  PM2.5   PM10     NO    NO2    NOx   NH3    CO   SO2     O3  \
# 0 2020-01-01  457.8  316.1  114.4   88.3   81.9  42.9  7.43  35.3   94.9
# 1 2020-01-02  171.9  110.6   36.1   87.6   67.7   2.7  3.39   4.5  188.4
# 2 2020-01-03   54.5  342.8  110.8   86.6  172.9  47.7  1.88  89.2   72.8
# 3 2020-01-04  360.7  467.9  101.5   92.5   45.9  12.0  5.44  62.8  178.4
# 4 2020-01-05  299.4   90.7  188.0  111.4   78.4  37.9  9.41   6.9   58.4
#
#    Benzene  Toluene  Xylene    AQI    AQI_Bucket
# 0     2.58     3.18    7.04  311.3     Very Poor
# 1     8.45     3.86    7.14  418.2      Moderate
# 2     6.44    21.79    9.07  381.8  Satisfactory
# 3     5.48    15.48    5.77   89.6          Poor
# 4    15.91    20.80    4.23  232.2          Good
