# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.layers import (
    Input,
    Dense,
    Dropout,
    Conv1D,
    GlobalAveragePooling1D,
    MultiHeadAttention,
    LayerNormalization,
    BatchNormalization
)

from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

# =========================
# LOAD
# =========================
X = np.load("../data/X_class.npy")
y = np.load("../data/y_class.npy")

print("X:", X.shape)
print("y:", y.shape)

# CLASS DISTRIBUTION
unique, counts = np.unique(y, return_counts=True)

print("Class distribution:")
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}")

# ONE HOT
num_classes = 6
y_cat = to_categorical(y, num_classes)

# SPLIT
X_train, X_test, y_train, y_test, y_train_raw, y_test_raw = train_test_split(
    X,
    y_cat,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# CLASS WEIGHTS
weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_raw),
    y=y_train_raw
)

class_weights = dict(enumerate(weights))

print("Class weights:", class_weights)

# =========================
# MODEL
# =========================
seq_input = Input(shape=(X.shape[1], X.shape[2]))

x = Conv1D(64, 3, padding='causal', activation='relu')(seq_input)
x = BatchNormalization()(x)

x = Conv1D(64, 3, padding='causal', dilation_rate=2, activation='relu')(x)
x = BatchNormalization()(x)

x = Conv1D(64, 3, padding='causal', dilation_rate=4, activation='relu')(x)

attn = MultiHeadAttention(num_heads=4, key_dim=16)(x, x)

x = x + attn
x = LayerNormalization()(x)

x = GlobalAveragePooling1D()(x)

x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)

x = Dense(64, activation='relu')(x)
x = Dropout(0.3)(x)

output = Dense(num_classes, activation='softmax')(x)

model = Model(seq_input, output)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# =========================
# CALLBACKS
# =========================
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=8,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3
)

# =========================
# TRAIN
# =========================
history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=20,
    batch_size=64,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weights
)

# =========================
# PREDICT
# =========================
pred_probs = model.predict(X_test)

y_pred = np.argmax(pred_probs, axis=1)
y_true = y_test_raw

# =========================
# METRICS
# =========================
acc = accuracy_score(y_true, y_pred)

print("Final Accuracy:", acc * 100)

print(classification_report(y_true, y_pred))

print(confusion_matrix(y_true, y_pred))

# =========================
# PLOTS
# =========================
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.legend()
plt.show()
# Out:
# X: (1790, 30, 16)
# y: (1790,)
# Class distribution:
# Class 0: 180
# Class 1: 183
# Class 2: 344
# Class 3: 351
# Class 4: 360
# Class 5: 372
# Class weights: {0: np.float64(1.6574074074074074), 1: np.float64(1.634703196347032), 2: np.float64(0.8678787878787879), 3: np.float64(0.8493475682087782), 4: np.float64(0.8287037037037037), 5: np.float64(0.8008948545861297)}
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 30, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 30, 64)    │      3,136 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 64)    │        256 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 30, 64)    │     12,352 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 64)    │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 30, 64)    │     12,352 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 64)    │     16,640 │ conv1d_5[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 30, 64)    │          0 │ conv1d_5[0][0],   │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 64)    │        128 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      8,320 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 6)         │        390 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 62,086 (242.52 KB)
#  Trainable params: 61,830 (241.52 KB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.1590 - loss: 1.8373 - val_accuracy: 0.1986 - val_loss: 1.7847 - learning_rate: 0.0010
# Epoch 2/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1563 - loss: 1.8095 - val_accuracy: 0.1882 - val_loss: 1.7849 - learning_rate: 0.0010
# Epoch 3/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2026 - loss: 1.8014 - val_accuracy: 0.2021 - val_loss: 1.7990 - learning_rate: 0.0010
# Epoch 4/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1808 - loss: 1.7881 - val_accuracy: 0.1916 - val_loss: 1.8838 - learning_rate: 0.0010
# Epoch 5/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1878 - loss: 1.7805 - val_accuracy: 0.0871 - val_loss: 1.9520 - learning_rate: 5.0000e-04
# Epoch 6/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2157 - loss: 1.7562 - val_accuracy: 0.0871 - val_loss: 2.0062 - learning_rate: 5.0000e-04
# Epoch 7/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2638 - loss: 1.7389 - val_accuracy: 0.0592 - val_loss: 2.0100 - learning_rate: 5.0000e-04
# Epoch 8/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2646 - loss: 1.7191 - val_accuracy: 0.0592 - val_loss: 2.0091 - learning_rate: 2.5000e-04
# Epoch 9/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3031 - loss: 1.7015 - val_accuracy: 0.0557 - val_loss: 2.0382 - learning_rate: 2.5000e-04
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Final Accuracy: 17.59776536312849
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        36
#            1       0.00      0.00      0.00        37
#            2       0.17      0.30      0.22        69
#            3       0.18      0.60      0.28        70
#            4       0.00      0.00      0.00        72
#            5       0.00      0.00      0.00        74
#
#     accuracy                           0.18       358
#    macro avg       0.06      0.15      0.08       358
# weighted avg       0.07      0.18      0.10       358
#
# [[ 0  0 15 21  0  0]
#  [ 0  0 10 27  0  0]
#  [ 0  0 21 48  0  0]
#  [ 0  0 28 42  0  0]
#  [ 0  0 33 39  0  0]
#  [ 0  0 19 55  0  0]]
# C:\Users\hi\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\hi\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\hi\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
